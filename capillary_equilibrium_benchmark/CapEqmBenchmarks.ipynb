# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# # Benchmark 1
#
# Read in data

# %%
# Semi-analytical solution
names = ['x1', 'Sw1', 'x2', 'Sw2', 'x3', 'Sw3', 'x4', 'Sw4', 'x5', 'Sw5']
capeqm1_sol = pd.read_csv('./capeqm1/sol_capeqm1.txt', delim_whitespace=True, names=names)

# MOOSE solution
capeqm1_moose1 = pd.read_csv('./capeqm1/capeqm1_csv_snw_0383.csv')
capeqm1_moose2 = pd.read_csv('./capeqm1/capeqm1_csv_snw_0839.csv')
capeqm1_moose3 = pd.read_csv('./capeqm1/capeqm1_csv_snw_1393.csv')
capeqm1_moose4 = pd.read_csv('./capeqm1/capeqm1_csv_snw_1975.csv')
capeqm1_moose5 = pd.read_csv('./capeqm1/capeqm1_csv_snw_2816.csv')

# %%
plt.plot(capeqm1_sol['x1'], capeqm1_sol['Sw1'], label = '1e4 s')
plt.plot(capeqm1_moose1['x'], 1-capeqm1_moose1['snw'], 'o', c='C0')
plt.plot(capeqm1_sol['x2'], capeqm1_sol['Sw2'], label = '4e4 s')
plt.plot(capeqm1_moose2['x'], 1-capeqm1_moose2['snw'], 'o', c='C1')
plt.plot(capeqm1_sol['x3'], capeqm1_sol['Sw3'], label = '1e5 s')
plt.plot(capeqm1_moose3['x'], 1-capeqm1_moose3['snw'], 'o', c='C2')
plt.plot(capeqm1_sol['x4'], capeqm1_sol['Sw4'], label = '2e5 s')
plt.plot(capeqm1_moose4['x'], 1-capeqm1_moose4['snw'], 'o', c='C3')
plt.plot(capeqm1_sol['x5'], capeqm1_sol['Sw5'], label = '4e5 s')
plt.plot(capeqm1_moose5['x'], 1-capeqm1_moose5['snw'], 'o', c='C4')
plt.legend()
plt.savefig('capeqm1.png', dpi=300)
